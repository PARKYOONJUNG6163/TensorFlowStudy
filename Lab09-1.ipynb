# %% [markdown]
# XOR문제

# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.array([[0,0], [0,1], [1,0], [1,1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
W = tf.Variable(tf.random_normal([2, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias') # bias는 out의 개수와 같음

hypothesis = tf.sigmoid(tf.matmul(X, W)+b) #활성함수 시그모이드

cost = -tf.reduce_sum(Y *tf.log(hypothesis) + (1-Y) * tf.log(1 - hypothesis)) # 축 1로 해서 합을 구하고 평균을 냄
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# 4개이므로 test와 train 나누지 않음

predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuarcy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001) :
        sess.run(train, feed_dict={X: x_data, Y:y_data})
        if step % 100 == 0:
            print(step, sess.run(cost, feed_dict={X:x_data, Y:y_data}), sess.run(W))
    
    h,c,a = sess.run([hypothesis, predicted, accuarcy], feed_dict={X:x_data, Y:y_data})
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 3.5949936 [[ 1.0325938 ]
#  [-0.67617184]]
# 100 2.7746463 [[ 0.01903986]
#  [-0.1253309 ]]
# 200 2.7726288 [[-0.00518869]
#  [-0.01667146]]
# 300 2.7725902 [[-0.00179087]
#  [-0.00270394]]
# 400 2.772589 [[-0.00042583]
#  [-0.00049844]]
# 500 2.7725887 [[-9.214056e-05]
#  [-9.790563e-05]]
# 600 2.772589 [[-1.9297700e-05]
#  [-1.9757987e-05]]
# 700 2.7725887 [[-3.991225e-06]
#  [-4.016396e-06]]
# 800 2.7725887 [[-8.2622091e-07]
#  [-8.2754957e-07]]
# 900 2.7725887 [[-1.8249108e-07]
#  [-1.8381974e-07]]
# 1000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 1900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 2900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 3900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 4900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 5900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 6900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 7900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 8900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9100 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9200 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9300 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9400 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9500 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9600 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9700 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9800 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 9900 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
# 10000 2.7725887 [[-1.2884695e-07]
#  [-1.3017561e-07]]
#
# Hypothesis:  [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
# Correct:  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Accuracy:  0.5

# %% [markdown]
# 잘 작동하지 않음!
