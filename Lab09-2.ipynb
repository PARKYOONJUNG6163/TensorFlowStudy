# %% [markdown]
# Nerual Net

# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.array([[0,0], [0,1], [1,0], [1,1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

W1 = tf.Variable(tf.random_normal([2, 2]), name='weight1')
b1 = tf.Variable(tf.random_normal([2]), name='bias1') # bias는 out의 개수와 같음
layer1 = tf.sigmoid(tf.matmul(X, W1)+b1) #활성함수 시그모이드

W2 = tf.Variable(tf.random_normal([2, 1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2') # bias는 out의 개수와 같음
hypothesis = tf.sigmoid(tf.matmul(layer1, W2)+b2) #활성함수 시그모이드

cost = -tf.reduce_sum(Y *tf.log(hypothesis) + (1-Y) * tf.log(1 - hypothesis)) # 축 1로 해서 합을 구하고 평균을 냄
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# 4개이므로 test와 train 나누지 않음

predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuarcy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001) :
        sess.run(train, feed_dict={X: x_data, Y:y_data})
        if step % 100 == 0:
            print(step, sess.run(cost, feed_dict={X:x_data, Y:y_data}), sess.run([W1, W2]))
    
    h,c,a = sess.run([hypothesis, predicted, accuarcy], feed_dict={X:x_data, Y:y_data})
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 3.1102593 [array([[-1.170414 ,  1.4457289],
#        [-1.5405976, -2.1940522]], dtype=float32), array([[0.39769998],
#        [1.5525593 ]], dtype=float32)]
# 100 2.5454967 [array([[-1.1108016,  1.7328786],
#        [-1.4532208, -2.6933181]], dtype=float32), array([[-0.25416875],
#        [ 2.0054994 ]], dtype=float32)]
# 200 2.3014374 [array([[-1.2561064,  2.4404435],
#        [-1.7967725, -3.3016112]], dtype=float32), array([[-0.9996132],
#        [ 2.6786659]], dtype=float32)]
# 300 2.0591207 [array([[-1.4911029,  3.0262642],
#        [-2.4109123, -3.9130764]], dtype=float32), array([[-1.7874929],
#        [ 3.3422952]], dtype=float32)]
# 400 1.8588748 [array([[-1.7694346,  3.429841 ],
#        [-3.0944598, -4.4503407]], dtype=float32), array([[-2.5437195],
#        [ 3.8826795]], dtype=float32)]
# 500 1.7202682 [array([[-2.0466712,  3.6971998],
#        [-3.7121332, -4.898276 ]], dtype=float32), array([[-3.1755517],
#        [ 4.3036366]], dtype=float32)]
# 600 1.6321408 [array([[-2.2916565,  3.87942  ],
#        [-4.2227817, -5.2665567]], dtype=float32), array([[-3.6715512],
#        [ 4.632514 ]], dtype=float32)]
# 700 1.5757551 [array([[-2.4970293,  4.0104966],
#        [-4.6378455, -5.5714664]], dtype=float32), array([[-4.061207],
#        [ 4.895211]], dtype=float32)]
# 800 1.5381582 [array([[-2.6674898,  4.109914 ],
#        [-4.979365 , -5.828053 ]], dtype=float32), array([[-4.3743906],
#        [ 5.110812 ]], dtype=float32)]
# 900 1.511905 [array([[-2.8101091,  4.188683 ],
#        [-5.2658625, -6.047869 ]], dtype=float32), array([[-4.632668],
#        [ 5.292257]], dtype=float32)]
# 1000 1.4927938 [array([[-2.9310608,  4.2532682],
#        [-5.5108094, -6.2392926]], dtype=float32), array([[-4.85063  ],
#        [ 5.4482245]], dtype=float32)]
# 1100 1.4783832 [array([[-3.0351014,  4.307648 ],
#        [-5.723746 , -6.4083576]], dtype=float32), array([[-5.038163 ],
#        [ 5.5846457]], dtype=float32)]
# 1200 1.4671919 [array([[-3.1257832,  4.354407 ],
#        [-5.9114895, -6.5594735]], dtype=float32), array([[-5.2021327],
#        [ 5.705676 ]], dtype=float32)]
# 1300 1.458286 [array([[-3.2057533,  4.3952885],
#        [-6.0790086, -6.6959243]], dtype=float32), array([[-5.347426],
#        [ 5.814321]], dtype=float32)]
# 1400 1.4510503 [array([[-3.2770045,  4.431525 ],
#        [-6.2299943, -6.820189 ]], dtype=float32), array([[-5.477617],
#        [ 5.912807]], dtype=float32)]
# 1500 1.4450693 [array([[-3.3410575,  4.464006 ],
#        [-6.3672466, -6.9341955]], dtype=float32), array([[-5.5953794],
#        [ 6.002827 ]], dtype=float32)]
# 1600 1.4400501 [array([[-3.3990927,  4.493393 ],
#        [-6.4929414, -7.0394516]], dtype=float32), array([[-5.702762 ],
#        [ 6.0856867]], dtype=float32)]
# 1700 1.4357843 [array([[-3.4520357,  4.5201936],
#        [-6.608785 , -7.1371727]], dtype=float32), array([[-5.8013544],
#        [ 6.162418 ]], dtype=float32)]
# 1800 1.4321178 [array([[-3.5006278,  4.5448046],
#        [-6.7161474, -7.228332 ]], dtype=float32), array([[-5.892423 ],
#        [ 6.2338495]], dtype=float32)]
# 1900 1.4289353 [array([[-3.545465 ,  4.5675397],
#        [-6.8161354, -7.313737 ]], dtype=float32), array([[-5.9769874],
#        [ 6.300651 ]], dtype=float32)]
# 2000 1.4261489 [array([[-3.5870357,  4.588649 ],
#        [-6.9096556, -7.3940477]], dtype=float32), array([[-6.0558753],
#        [ 6.36338  ]], dtype=float32)]
# 2100 1.423691 [array([[-3.625741 ,  4.6083393],
#        [-6.997465 , -7.469831 ]], dtype=float32), array([[-6.1297765],
#        [ 6.422495 ]], dtype=float32)]
# 2200 1.4215066 [array([[-3.6619172,  4.62678  ],
#        [-7.080195 , -7.541557 ]], dtype=float32), array([[-6.199248 ],
#        [ 6.4783845]], dtype=float32)]
# 2300 1.4195545 [array([[-3.6958485,  4.6441135],
#        [-7.158383 , -7.609628 ]], dtype=float32), array([[-6.2647777],
#        [ 6.531379 ]], dtype=float32)]
# 2400 1.4177996 [array([[-3.7277725,  4.6604586],
#        [-7.232485 , -7.6743913]], dtype=float32), array([[-6.326773],
#        [ 6.58176 ]], dtype=float32)]
# 2500 1.4162141 [array([[-3.7578933,  4.675916 ],
#        [-7.3028917, -7.736147 ]], dtype=float32), array([[-6.3855815],
#        [ 6.6297693]], dtype=float32)]
# 2600 1.4147751 [array([[-3.7863882,  4.6905737],
#        [-7.369943 , -7.795156 ]], dtype=float32), array([[-6.4415045],
#        [ 6.6756177]], dtype=float32)]
# 2700 1.4134641 [array([[-3.8134096,  4.704506 ],
#        [-7.4339347, -7.8516474]], dtype=float32), array([[-6.494802],
#        [ 6.719491]], dtype=float32)]
# 2800 1.4122641 [array([[-3.8390908,  4.717779 ],
#        [-7.4951253, -7.905825 ]], dtype=float32), array([[-6.5457025],
#        [ 6.761549 ]], dtype=float32)]
# 2900 1.4111623 [array([[-3.863546 ,  4.730449 ],
#        [-7.553744 , -7.9578686]], dtype=float32), array([[-6.5944037],
#        [ 6.801933 ]], dtype=float32)]
# 3000 1.4101471 [array([[-3.8868792,  4.742567 ],
#        [-7.6099887, -8.007935 ]], dtype=float32), array([[-6.6410832],
#        [ 6.8407736]], dtype=float32)]
# 3100 1.4092083 [array([[-3.9091802,  4.7541757],
#        [-7.664039 , -8.056166 ]], dtype=float32), array([[-6.6858974],
#        [ 6.878181 ]], dtype=float32)]
# 3200 1.4083395 [array([[-3.9305305,  4.765314 ],
#        [-7.716057 , -8.102689 ]], dtype=float32), array([[-6.728985 ],
#        [ 6.9142575]], dtype=float32)]
# 3300 1.4075315 [array([[-3.951   ,  4.776018],
#        [-7.766185, -8.147621]], dtype=float32), array([[-6.7704706],
#        [ 6.9490924]], dtype=float32)]
# 3400 1.4067788 [array([[-3.970653,  4.786319],
#        [-7.814552, -8.191064]], dtype=float32), array([[-6.810464 ],
#        [ 6.9827695]], dtype=float32)]
# 3500 1.4060762 [array([[-3.9895484,  4.796245 ],
#        [-7.8612742, -8.233112 ]], dtype=float32), array([[-6.8490667],
#        [ 7.0153613]], dtype=float32)]
# 3600 1.405418 [array([[-4.0077376,  4.80582  ],
#        [-7.9064565, -8.273852 ]], dtype=float32), array([[-6.88637 ],
#        [ 7.046935]], dtype=float32)]
# 3700 1.4048018 [array([[-4.0252666,  4.8150687],
#        [-7.950196 , -8.31336  ]], dtype=float32), array([[-6.9224577],
#        [ 7.0775523]], dtype=float32)]
# 3800 1.404223 [array([[-4.04218  ,  4.82401  ],
#        [-7.9925776, -8.351708 ]], dtype=float32), array([[-6.9574018],
#        [ 7.107269 ]], dtype=float32)]
# 3900 1.4036775 [array([[-4.058514,  4.832664],
#        [-8.033684, -8.388961]], dtype=float32), array([[-6.9912724],
#        [ 7.1361365]], dtype=float32)]
# 4000 1.403164 [array([[-4.074306,  4.841046],
#        [-8.073583, -8.425179]], dtype=float32), array([[-7.024131 ],
#        [ 7.1642017]], dtype=float32)]
# 4100 1.4026785 [array([[-4.089586,  4.849175],
#        [-8.112346, -8.460417]], dtype=float32), array([[-7.0560346],
#        [ 7.191507 ]], dtype=float32)]
# 4200 1.4022198 [array([[-4.1043854,  4.857063 ],
#        [-8.150032 , -8.494722 ]], dtype=float32), array([[-7.087036],
#        [ 7.218093]], dtype=float32)]
# 4300 1.4017854 [array([[-4.1187305,  4.864725 ],
#        [-8.186697 , -8.528147 ]], dtype=float32), array([[-7.1171846],
#        [ 7.2439957]], dtype=float32)]
# 4400 1.401373 [array([[-4.132648 ,  4.8721695],
#        [-8.222398 , -8.560734 ]], dtype=float32), array([[-7.1465254],
#        [ 7.2692494]], dtype=float32)]
# 4500 1.4009814 [array([[-4.1461573,  4.8794117],
#        [-8.257178 , -8.592522 ]], dtype=float32), array([[-7.1750975],
#        [ 7.2938857]], dtype=float32)]
# 4600 1.4006097 [array([[-4.1592836,  4.886461 ],
#        [-8.291087 , -8.62355  ]], dtype=float32), array([[-7.20294  ],
#        [ 7.3179336]], dtype=float32)]
# 4700 1.4002559 [array([[-4.1720448,  4.8933263],
#        [-8.324165 , -8.653851 ]], dtype=float32), array([[-7.230089 ],
#        [ 7.3414207]], dtype=float32)]
# 4800 1.3999178 [array([[-4.184459,  4.900018],
#        [-8.35645 , -8.68346 ]], dtype=float32), array([[-7.256576 ],
#        [ 7.3643723]], dtype=float32)]
# 4900 1.3995961 [array([[-4.1965446,  4.90654  ],
#        [-8.387976 , -8.712407 ]], dtype=float32), array([[-7.282433],
#        [ 7.386813]], dtype=float32)]
# 5000 1.3992884 [array([[-4.2083154,  4.9129043],
#        [-8.418779 , -8.740721 ]], dtype=float32), array([[-7.307689 ],
#        [ 7.4087634]], dtype=float32)]
# 5100 1.3989942 [array([[-4.2197876,  4.9191184],
#        [-8.448893 , -8.768426 ]], dtype=float32), array([[-7.332369],
#        [ 7.430246]], dtype=float32)]
# 5200 1.3987129 [array([[-4.2309732,  4.925187 ],
#        [-8.478348 , -8.79555  ]], dtype=float32), array([[-7.3564997],
#        [ 7.4512787]], dtype=float32)]
# 5300 1.3984432 [array([[-4.2418876,  4.931117 ],
#        [-8.507166 , -8.822113 ]], dtype=float32), array([[-7.3801036],
#        [ 7.47188  ]], dtype=float32)]
# 5400 1.3981845 [array([[-4.2525425,  4.9369164],
#        [-8.535378 , -8.848145 ]], dtype=float32), array([[-7.4032025],
#        [ 7.4920683]], dtype=float32)]
# 5500 1.3979369 [array([[-4.262947,  4.942589],
#        [-8.563007, -8.873657]], dtype=float32), array([[-7.4258184],
#        [ 7.511859 ]], dtype=float32)]
# 5600 1.3976992 [array([[-4.2731113,  4.9481373],
#        [-8.590077 , -8.898676 ]], dtype=float32), array([[-7.4479694],
#        [ 7.5312676]], dtype=float32)]
# 5700 1.3974701 [array([[-4.283048,  4.95357 ],
#        [-8.616609, -8.923219]], dtype=float32), array([[-7.469674],
#        [ 7.550309]], dtype=float32)]
# 5800 1.39725 [array([[-4.2927666,  4.958892 ],
#        [-8.642622 , -8.947299 ]], dtype=float32), array([[-7.4909506],
#        [ 7.568996 ]], dtype=float32)]
# 5900 1.397038 [array([[-4.302274 ,  4.9641037],
#        [-8.668138 , -8.970938 ]], dtype=float32), array([[-7.511814 ],
#        [ 7.5873413]], dtype=float32)]
# 6000 1.3968344 [array([[-4.311579 ,  4.9692125],
#        [-8.693173 , -8.99415  ]], dtype=float32), array([[-7.53228 ],
#        [ 7.605358]], dtype=float32)]
# 6100 1.3966377 [array([[-4.3206906,  4.9742227],
#        [-8.717748 , -9.0169525]], dtype=float32), array([[-7.552364],
#        [ 7.623057]], dtype=float32)]
# 6200 1.3964489 [array([[-4.329614,  4.979136],
#        [-8.741876, -9.039357]], dtype=float32), array([[-7.5720787],
#        [ 7.64045  ]], dtype=float32)]
# 6300 1.396266 [array([[-4.3383594,  4.983958 ],
#        [-8.765573 , -9.061377 ]], dtype=float32), array([[-7.5914373],
#        [ 7.657546 ]], dtype=float32)]
# 6400 1.3960892 [array([[-4.346928 ,  4.9886904],
#        [-8.788854 , -9.083023 ]], dtype=float32), array([[-7.610453 ],
#        [ 7.6743546]], dtype=float32)]
# 6500 1.3959188 [array([[-4.3553324,  4.9933376],
#        [-8.811733 , -9.104312 ]], dtype=float32), array([[-7.6291375],
#        [ 7.690886 ]], dtype=float32)]
# 6600 1.3957541 [array([[-4.3635736,  4.997896 ],
#        [-8.834224 , -9.125252 ]], dtype=float32), array([[-7.6475005],
#        [ 7.707151 ]], dtype=float32)]
# 6700 1.3955951 [array([[-4.371659,  5.002377],
#        [-8.856339, -9.145857]], dtype=float32), array([[-7.6655545],
#        [ 7.7231555]], dtype=float32)]
# 6800 1.3954403 [array([[-4.3795953,  5.006783 ],
#        [-8.878093 , -9.166133 ]], dtype=float32), array([[-7.6833076],
#        [ 7.738909 ]], dtype=float32)]
# 6900 1.395291 [array([[-4.3873863,  5.011109 ],
#        [-8.899494 , -9.186096 ]], dtype=float32), array([[-7.700771 ],
#        [ 7.7544184]], dtype=float32)]
# 7000 1.3951461 [array([[-4.3950377,  5.015368 ],
#        [-8.920551 , -9.205752 ]], dtype=float32), array([[-7.7179537],
#        [ 7.769692 ]], dtype=float32)]
# 7100 1.395006 [array([[-4.402553 ,  5.0195503],
#        [-8.941281 , -9.225108 ]], dtype=float32), array([[-7.734863 ],
#        [ 7.7847366]], dtype=float32)]
# 7200 1.3948698 [array([[-4.409939 ,  5.0236692],
#        [-8.96169  , -9.244176 ]], dtype=float32), array([[-7.7515097],
#        [ 7.7995596]], dtype=float32)]
# 7300 1.3947378 [array([[-4.417194,  5.02772 ],
#        [-8.981785, -9.262963]], dtype=float32), array([[-7.7678986],
#        [ 7.8141646]], dtype=float32)]
# 7400 1.3946106 [array([[-4.424328 ,  5.0317054],
#        [-9.001581 , -9.281478 ]], dtype=float32), array([[-7.78404 ],
#        [ 7.828562]], dtype=float32)]
# 7500 1.3944862 [array([[-4.4313416,  5.035633 ],
#        [-9.021086 , -9.299727 ]], dtype=float32), array([[-7.7999406],
#        [ 7.8427553]], dtype=float32)]
# 7600 1.3943654 [array([[-4.438242,  5.039499],
#        [-9.040304, -9.317724]], dtype=float32), array([[-7.815607 ],
#        [ 7.8567495]], dtype=float32)]
# 7700 1.3942482 [array([[-4.445027,  5.043302],
#        [-9.059246, -9.335467]], dtype=float32), array([[-7.8310466],
#        [ 7.8705516]], dtype=float32)]
# 7800 1.3941345 [array([[-4.4517045,  5.0470486],
#        [-9.077922 , -9.352967 ]], dtype=float32), array([[-7.8462634],
#        [ 7.8841653]], dtype=float32)]
# 7900 1.3940234 [array([[-4.4582767,  5.0507426],
#        [-9.096332 , -9.370231 ]], dtype=float32), array([[-7.8612666],
#        [ 7.897596 ]], dtype=float32)]
# 8000 1.393916 [array([[-4.4647484,  5.054383 ],
#        [-9.114488 , -9.387266 ]], dtype=float32), array([[-7.8760595],
#        [ 7.9108496]], dtype=float32)]
# 8100 1.3938105 [array([[-4.4711204,  5.05797  ],
#        [-9.1324005, -9.404073 ]], dtype=float32), array([[-7.89065  ],
#        [ 7.9239316]], dtype=float32)]
# 8200 1.3937091 [array([[-4.477395 ,  5.061507 ],
#        [-9.1500635, -9.420661 ]], dtype=float32), array([[-7.905042 ],
#        [ 7.9368424]], dtype=float32)]
# 8300 1.393609 [array([[-4.4835744,  5.064996 ],
#        [-9.1675005, -9.437038 ]], dtype=float32), array([[-7.9192414],
#        [ 7.9495907]], dtype=float32)]
# 8400 1.3935132 [array([[-4.4896636,  5.0684342],
#        [-9.184703 , -9.453206 ]], dtype=float32), array([[-7.9332533],
#        [ 7.9621778]], dtype=float32)]
# 8500 1.3934178 [array([[-4.4956613,  5.0718255],
#        [-9.201684 , -9.4691725]], dtype=float32), array([[-7.947082],
#        [ 7.974608]], dtype=float32)]
# 8600 1.3933266 [array([[-4.501575,  5.075171],
#        [-9.21845 , -9.48494 ]], dtype=float32), array([[-7.960734 ],
#        [ 7.9868865]], dtype=float32)]
# 8700 1.3932366 [array([[-4.5074067,  5.078472 ],
#        [-9.235005 , -9.500514 ]], dtype=float32), array([[-7.97421  ],
#        [ 7.9990163]], dtype=float32)]
# 8800 1.3931489 [array([[-4.513152,  5.081729],
#        [-9.251348, -9.515902]], dtype=float32), array([[-7.9875183],
#        [ 8.011    ]], dtype=float32)]
# 8900 1.3930635 [array([[-4.51882  ,  5.0849447],
#        [-9.267491 , -9.531105 ]], dtype=float32), array([[-8.00066 ],
#        [ 8.022849]], dtype=float32)]
# 9000 1.3929802 [array([[-4.524411,  5.08812 ],
#        [-9.283438, -9.546128]], dtype=float32), array([[-8.013642],
#        [ 8.034547]], dtype=float32)]
# 9100 1.3928988 [array([[-4.5299225,  5.091257 ],
#        [-9.299191 , -9.560971 ]], dtype=float32), array([[-8.026466],
#        [ 8.046121]], dtype=float32)]
# 9200 1.3928196 [array([[-4.5353627,  5.094356 ],
#        [-9.314758 , -9.575646 ]], dtype=float32), array([[-8.039131],
#        [ 8.057554]], dtype=float32)]
# 9300 1.3927422 [array([[-4.5407286,  5.0974092],
#        [-9.330144 , -9.590153 ]], dtype=float32), array([[-8.051657],
#        [ 8.06886 ]], dtype=float32)]
# 9400 1.3926661 [array([[-4.5460277,  5.1004267],
#        [-9.345351 , -9.604501 ]], dtype=float32), array([[-8.064021],
#        [ 8.080048]], dtype=float32)]
# 9500 1.3925924 [array([[-4.551254,  5.103411],
#        [-9.360376, -9.61868 ]], dtype=float32), array([[-8.076258],
#        [ 8.091104]], dtype=float32)]
# 9600 1.3925197 [array([[-4.556418 ,  5.1063643],
#        [-9.375234 , -9.6327095]], dtype=float32), array([[-8.088339],
#        [ 8.102036]], dtype=float32)]
# 9700 1.3924494 [array([[-4.56151  ,  5.109273 ],
#        [-9.389926 , -9.6465845]], dtype=float32), array([[-8.100295],
#        [ 8.112856]], dtype=float32)]
# 9800 1.39238 [array([[-4.566541,  5.112149],
#        [-9.40446 , -9.660308]], dtype=float32), array([[-8.112109],
#        [ 8.123563]], dtype=float32)]
# 9900 1.3923116 [array([[-4.571513 ,  5.1149964],
#        [-9.41882  , -9.673889 ]], dtype=float32), array([[-8.123795],
#        [ 8.134155]], dtype=float32)]
# 10000 1.3922455 [array([[-4.5764194,  5.11781  ],
#        [-9.433033 , -9.687317 ]], dtype=float32), array([[-8.13536  ],
#        [ 8.1446295]], dtype=float32)]
#
# Hypothesis:  [[0.00170445]
#  [0.499209  ]
#  [0.99850416]
#  [0.5005822 ]]
# Correct:  [[0.]
#  [0.]
#  [1.]
#  [1.]]
# Accuracy:  0.5

# %% [markdown]
# Lab09-1과의 차이는 레이어를 두개를 뒀다는 것!
